# %%
import pandas as pd
import numpy as np
import geopandas as gpd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
crime = pd.read_csv("crime.csv")
crime.head()
# Out:
#         Neighborhood  Sector # Population (2010)  \
# 0   Allegheny Center         3               933
# 1     Allegheny West         3               462
# 2          Allentown         6             2,500
# 3          Arlington         7             1,869
# 4  Arlington Heights         7               244
#
#    #Part 1 (Major Crime) Reports (2010)  #Part 2 Reports (2010)  \
# 0                                    71                     141
# 1                                    38                      49
# 2                                   159                     252
# 3                                    50                      84
# 4                                    19                      37
#
#    #Other Police Reports (2010)  Part 1 Crime per 100 Persons (2010)  \
# 0                            46                                  7.6
# 1                            31                                  8.2
# 2                           160                                  6.4
# ...

# %%
def filter_func(crime, lower_bound):
    return (crime['#Rape (2010)'] < lower_bound)

robberyFiltered = crime.groupby(crime.index).filter(filter_func, lower_bound=1)
robberyFiltered.plot()

# %%
def filter_func(crime, lower_bound):
    return (crime['#Rape (2010)'] < lower_bound)

robberyFiltered = crime.groupby(crime.index).filter(filter_func, lower_bound=1)
robberyFiltered.head(100)
# Out:
#                 Neighborhood  Sector # Population (2010)  \
# 1             Allegheny West         3               462
# 4          Arlington Heights         7               244
# 5                 Banksville         5             4,144
# 6          Bedford Dwellings        15             1,202
# 8                Beltzhoover         6             1,925
# 10                     Bluff        15             6,600
# 11                   Bon Air         6               808
# 14      California-Kirkbride         3               761
# 20            Chartiers City         4               477
# 21                   Chateau         3                11
# 23          Crawford-Roberts        15             2,256
# 24          Duquesne Heights         6             2,425
# 26             East Carnegie         4               570
# 27                East Hills        11             3,169
# 29                   Elliott         4             2,381
# ...

# %%
lower_bound = 1
neighborhood[]
if (crime['#Rape (2010)'] < lower_bound) and (crime['#Murder (2010)'] < lower_bound)

# %%
crime.plot()

# %%
rows, columns = crime.shape

# %%
crime[['Neighborhood', '#Rape (2010)', '#Murder (2010)', '#Robbery (2010)']]
# Out:
#                  Neighborhood  #Rape (2010)  #Murder (2010)  #Robbery (2010)
# 0            Allegheny Center             2               0                9
# 1              Allegheny West             0               1                4
# 2                   Allentown             2               0               15
# 3                   Arlington             1               0                8
# 4           Arlington Heights             0               0                4
# 5                  Banksville             0               0                2
# 6           Bedford Dwellings             0               0                7
# 7                   Beechview             1               1                7
# 8                 Beltzhoover             0               1                6
# 9                  Bloomfield             3               0               45
# 10                      Bluff             0               0               12
# ...

# %%
crime[['Neighborhood', '#Rape (2010)', '#Murder (2010)', '#Robbery (2010)', '#Agr. Assault (2010)']].describe()
# Out:
#        #Rape (2010)  #Murder (2010)  #Robbery (2010)  #Agr. Assault (2010)
# count     90.000000       90.000000        90.000000             90.000000
# mean       0.722222        0.511111        11.533333             10.611111
# std        1.132044        0.950983        13.042885             10.519852
# min        0.000000        0.000000         0.000000              0.000000
# 25%        0.000000        0.000000         2.000000              3.250000
# 50%        0.000000        0.000000         7.000000              7.000000
# 75%        1.000000        1.000000        16.000000             14.750000
# max        6.000000        5.000000        63.000000             61.000000

# %%
crime[['Neighborhood','#Murder (2010)','#Rape (2010)']][crime['#Murder (2010)']<1]
# Out:
#                  Neighborhood  #Murder (2010)  #Rape (2010)
# 0            Allegheny Center               0             2
# 2                   Allentown               0             2
# 3                   Arlington               0             1
# 4           Arlington Heights               0             0
# 5                  Banksville               0             0
# 6           Bedford Dwellings               0             0
# 9                  Bloomfield               0             3
# 10                      Bluff               0             0
# 11                    Bon Air               0             0
# 12           Brighton Heights               0             2
# 13                  Brookline               0             1
# 16  Central Business District               0             4
# 17      Central Lawrenceville               0             1
# 18          Central Northside               0             1
# 19            Central Oakland               0             1
# ...

# %%
labels = ['Chartiers City', 'East Carnegie', '', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

# %%
plt.plot(crime['#Murder (2010)'], crime['#Rape (2010)'], 'o')
plt.show()

# %%
murder = crime[crime['#Murder (2010)'] == 0]

# %%
rape = murder[murder['#Rape (2010)'] ==0]

# %%
robbery = rape[rape['#Robbery (2010)'] ==0]

# %%
assault = robbery[robbery['#Agr. Assault (2010)'] < 10.6]

# %%
assault[['Neighborhood','#Murder (2010)','#Rape (2010)', '#Robbery (2010)', '#Agr. Assault (2010)']]
# Out:
#         Neighborhood  #Murder (2010)  #Rape (2010)  #Robbery (2010)  \
# 77         St. Clair               0             0                0
# 37              Hays               0             0                0
# 66         Ridgemont               0             0                0
# 24  Duquesne Heights               0             0                0
# 81    Swisshelm Park               0             0                0
# 20    Chartiers City               0             0                0
# 26     East Carnegie               0             0                0
# 80       Summer Hill               0             0                0
# 54     New Homestead               0             0                0
# 31         Fairywood               0             0                0
#
#     #Agr. Assault (2010)
# 77                     2
# 37                     1
# 66                     1
# 24                     4
# 81                     0
# 20                     4
# 26                     1
# ...

# %%
assault['Neighborhood'].count()
# Out:
# 3

# %%
crime.plot.bar(x='Neighborhood', y='#Rape (2010)')

# %%
crime[['Neighborhood','#Murder (2010)','#Rape (2010)']][crime['#Murder (2010)']<1].plot()
plt.plot.bar(murder.Neighborhood, murder['#Murder (2010)'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-e01ea12736db> in <module>()
#       1 crime[['Neighborhood','#Murder (2010)','#Rape (2010)']][crime['#Murder (2010)']<1].plot()
# ----> 2 plt.plot.bar(murder.Neighborhood, murder['#Murder (2010)'])
#
# AttributeError: 'function' object has no attribute 'bar'

# %%
crimesort = crime.sort_values(by=["Part 1 Crime per 100 Persons (2010)"], ascending=False)

graph = crimesort[64:].plot.barh(x="Neighborhood",y="Part 1 Crime per 100 Persons (2010)",figsize=(15,crime.shape[0] * 0.3), legend=None)
graph.set_xlabel("Crime per 100 Persons")
graph.get_figure().savefig('figure.pdf')

# %%
crimesort = crime.sort_values(by=["Part 1 Crime per 100 Persons (2010)"], ascending=True)
crimesort[['Neighborhood', 'Part 1 Crime per 100 Persons (2010)']].head(26)
# Out:
#            Neighborhood  Part 1 Crime per 100 Persons (2010)
# 31            Fairywood                                  0.3
# 54        New Homestead                                  0.7
# 45        Lincoln Place                                  1.0
# 80          Summer Hill                                  1.2
# 75  Squirrel Hill North                                  1.3
# 35           Glen Hazel                                  1.4
# 58              Oakwood                                  1.4
# 5            Banksville                                  1.5
# 78      Stanton Heights                                  1.5
# 10                Bluff                                  1.6
# 26        East Carnegie                                  1.6
# 55        North Oakland                                  1.7
# 13            Brookline                                  1.8
# 20       Chartiers City                                  1.9
# ...

# %%
crimesort = crime.sort_values(by=["Part 1 Crime per 100 Persons (2010)"], ascending=True)
crimesort[['Neighborhood', 'Part 1 Crime per 100 Persons (2010)']]
crimesort.iloc[:2]
# Out:
#      Neighborhood  Sector # Population (2010)  \
# 31      Fairywood         4             1,002
# 54  New Homestead         8               990
#
#     #Part 1 (Major Crime) Reports (2010)  #Part 2 Reports (2010)  \
# 31                                     3                       6
# 54                                     7                       4
#
#     #Other Police Reports (2010)  Part 1 Crime per 100 Persons (2010)  \
# 31                             9                                  0.3
# 54                             9                                  0.7
#
#     Part 2 Crime per 100 Persons (2010)  #Murder (2010)  #Rape (2010)  \
# 31                                  0.6               0             0
# 54                                  0.4               0             0
#
#     #Robbery (2010)  #Agr. Assault (2010)  #Burglary (2010)  \
# 31                0                     0                 1
# 54                0                     0                 1
#
# ...

# %%
crimesort.iloc[3]
# Out:
# Neighborhood                            Summer Hill
# Sector #                                          1
# Population (2010)                             1,051
# #Part 1 (Major Crime) Reports (2010)             13
# #Part 2 Reports (2010)                           22
# #Other Police Reports (2010)                     13
# Part 1 Crime per 100 Persons (2010)             1.2
# Part 2 Crime per 100 Persons (2010)             2.1
# #Murder (2010)                                    0
# #Rape (2010)                                      0
# #Robbery (2010)                                   0
# #Agr. Assault (2010)                              1
# #Burglary (2010)                                  2
# #Auto Theft (2010)                                2
# #Drug Violations (2010)                           1
# Name: 80, dtype: object

# %%
shortlist = assault.sort_values(by=["Part 1 Crime per 100 Persons (2010)"], ascending=False)

graph = shortlist[3:].plot.barh(x="Neighborhood",y="Part 1 Crime per 100 Persons (2010)",figsize=(20,crime.shape[0] * 0.1), legend=None)
graph.set_xlabel("Crime per 100 Persons")
graph.get_figure().savefig('shortlist.pdf')

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-8d22f13ee6ab> in <module>()
# ----> 1 shortlist.loc('Fairywood')
#
# /ihome/crc/install/python/miniconda3-3.7/lib/python3.7/site-packages/pandas/core/indexing.py in __call__(self, axis)
#      96
#      97         if axis is not None:
# ---> 98             axis = self.obj._get_axis_number(axis)
#      99         new_self.axis = axis
#     100         return new_self
#
# /ihome/crc/install/python/miniconda3-3.7/lib/python3.7/site-packages/pandas/core/generic.py in _get_axis_number(self, axis)
#     373                 pass
#     374         raise ValueError('No axis named {0} for object type {1}'
# --> 375                          .format(axis, type(self)))
#     376
#     377     def _get_axis_name(self, axis):
#
# ValueError: No axis named Fairywood for object type <class 'pandas.core.frame.DataFrame'>

# %%
crime.iloc[89]
# Out:
# Neighborhood                            Fairywood
# Sector #                                        4
# Population (2010)                           1,002
# #Part 1 (Major Crime) Reports (2010)            3
# #Part 2 Reports (2010)                          6
# #Other Police Reports (2010)                    9
# Part 1 Crime per 100 Persons (2010)           0.3
# Part 2 Crime per 100 Persons (2010)           0.6
# #Murder (2010)                                  0
# #Rape (2010)                                    0
# #Robbery (2010)                                 0
# #Agr. Assault (2010)                            0
# #Burglary (2010)                                1
# #Auto Theft (2010)                              0
# #Drug Violations (2010)                         0
# Name: 31, dtype: object
