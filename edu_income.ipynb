# %%
import pandas as pd
import numpy as np
import geopandas as gpd
edin = pd.read_csv("education-income.csv")
edin.head(30)
# Out:
#                  Neighborhood  Sector # Population (2010)  \
# 0            Allegheny Center         3               933
# 1              Allegheny West         3               462
# 2                   Allentown         6             2,500
# 3                   Arlington         7             1,869
# 4           Arlington Heights         7               244
# 5                  Banksville         5             4,144
# 6           Bedford Dwellings        15             1,202
# 7                   Beechview         5             7,974
# 8                 Beltzhoover         6             1,925
# 9                  Bloomfield        12             8,442
# 10                      Bluff        15             6,600
# 11                    Bon Air         6               808
# 12           Brighton Heights         2             7,247
# 13                  Brookline         5            13,214
# 14       California-Kirkbride         3               761
# ...

# %%
#CEL=community edution level
edin1=edin.drop(index=(edin.loc[(edin['Neighborhood']=='Chateau')].index))
edin1.head()
i=0
while i<=88:
    a=edin1.iloc[i,4]
    a1=float(a[:-1])
    b=edin1.iloc[i,5]
    b1=float(b[:-1])
    c=edin1.iloc[i,6]
    c1=float(c[:-1])
    d=edin1.iloc[i,7]
    d1=float(d[:-1])
    e=edin1.iloc[i,8]
    e1=float(e[:-1])
    k=a1+b1+c1+d1+e1
print(a1,b1,c1,d1,e1)
