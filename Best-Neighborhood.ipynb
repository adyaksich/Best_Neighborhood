# %% [markdown]
# Group Name:

# %% [markdown]
# Members: Rachel Farrell, Anna Yaksich, Jiangjiang Song

# %% [markdown]
# rmf101@pitt.edu, ady13@pitt.edu, jis110@pitt.edu

# %% [markdown]
# Best Neighborhood:

# %% [markdown]
# Metrics:

# %%
import pandas as pd
import numpy as np
import geopandas as gpd

# %%
import pandas as pd
import numpy as np
import geopandas as gpd
crime = pd.read_csv("crime.csv")
crime.head()
# Out:
#         Neighborhood  Sector # Population (2010)  \
# 0   Allegheny Center         3               933
# 1     Allegheny West         3               462
# 2          Allentown         6             2,500
# 3          Arlington         7             1,869
# 4  Arlington Heights         7               244
#
#    #Part 1 (Major Crime) Reports (2010)  #Part 2 Reports (2010)  \
# 0                                    71                     141
# 1                                    38                      49
# 2                                   159                     252
# 3                                    50                      84
# 4                                    19                      37
#
#    #Other Police Reports (2010)  Part 1 Crime per 100 Persons (2010)  \
# 0                            46                                  7.6
# 1                            31                                  8.2
# 2                           160                                  6.4
# 3                            48                                  2.7
# 4                            24                                  7.8
#
#    Part 2 Crime per 100 Persons (2010)  #Murder (2010)  #Rape (2010)  \
# 0                                 15.1               0             2
# 1                                 10.6               1             0
# 2                                 10.1               0             2
# 3                                  4.5               0             1
# 4                                 15.2               0             0
#
#    #Robbery (2010)  #Agr. Assault (2010)  #Burglary (2010)  \
# 0                9                     5                 8
# 1                4                     6                 6
# 2               15                    23                48
# 3                8                     5                15
# 4                4                     5                 5
#
#    #Auto Theft (2010)  #Drug Violations (2010)
# 0                   5                       31
# 1                   4                       12
# 2                  11                       66
# 3                   7                        9
# 4                   3                        7

# %%
#Filter out neighborhoods that have murder
def filter_murder(x, threshold):
    if len(x) < threshold:
        return False
    else:
        return True

# use the custom function to filter out rows
murder = crime.groupby("Neighborhood").filter(filter_murder, threshold=0)
# look at what neighborhoods are in the data now
murder.groupby("#Murder (2010)").count()
# Out:
#                 Neighborhood  Sector #  Population (2010)  \
# #Murder (2010)
# 0                         62        62                 62
# 1                         17        17                 17
# 2                          7         7                  7
# 3                          2         2                  2
# 4                          1         1                  1
# 5                          1         1                  1
#
#                 #Part 1 (Major Crime) Reports (2010)  #Part 2 Reports (2010)  \
# #Murder (2010)
# 0                                                 62                      62
# 1                                                 17                      17
# 2                                                  7                       7
# 3                                                  2                       2
# 4                                                  1                       1
# 5                                                  1                       1
#
#                 #Other Police Reports (2010)  \
# #Murder (2010)
# 0                                         62
# 1                                         17
# 2                                          7
# 3                                          2
# 4                                          1
# 5                                          1
#
#                 Part 1 Crime per 100 Persons (2010)  \
# #Murder (2010)
# 0                                                62
# 1                                                17
# 2                                                 7
# 3                                                 2
# 4                                                 1
# 5                                                 1
#
#                 Part 2 Crime per 100 Persons (2010)  #Rape (2010)  \
# #Murder (2010)
# 0                                                62            62
# 1                                                17            17
# 2                                                 7             7
# 3                                                 2             2
# 4                                                 1             1
# 5                                                 1             1
#
#                 #Robbery (2010)  #Agr. Assault (2010)  #Burglary (2010)  \
# #Murder (2010)
# 0                            62                    62                62
# 1                            17                    17                17
# 2                             7                     7                 7
# 3                             2                     2                 2
# 4                             1                     1                 1
# 5                             1                     1                 1
#
#                 #Auto Theft (2010)  #Drug Violations (2010)
# #Murder (2010)
# 0                               62                       62
# 1                               17                       17
# 2                                7                        7
# 3                                2                        2
# 4                                1                        1
# 5                                1                        1

# %%
crimes = crime['#Murder (2010)', '#Rape (2010)', '#Robbery (2010)', '#Agr. Assault']
def filter_func(crimes, lower_bound):
    for crimes in crime:
        if len(crimes) < lower_bound:
            return True
        else: 
            return False
    #return (crime['#Murder (2010)'] < lower_bound)



crimeFiltered = crimes.groupby(crime.index).filter(filter_func, lower_bound=1)

crimeFiltered.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('#Murder (2010)', '#Rape (2010)', '#Robbery (2010)', '#Agr. Assault')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-ffd8c23c8d1a> in <module>
# ----> 1 crimes = crime['#Murder (2010)', '#Rape (2010)', '#Robbery (2010)', '#Agr. Assault']
#       2 def filter_func(crimes, lower_bound):
#       3     for crimes in crime:
#       4         if len(crimes) < lower_bound:
#       5             return True
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('#Murder (2010)', '#Rape (2010)', '#Robbery (2010)', '#Agr. Assault')

# %%
def filter_func(crime, lower_bound):
    return (crime['#Rape (2010)'] < lower_bound)

rapeFiltered = crime.groupby(crime.index).filter(filter_func, lower_bound=1)

rapeFiltered.head(10)
# Out:
#             Neighborhood  Sector # Population (2010)  \
# 1         Allegheny West         3               462
# 4      Arlington Heights         7               244
# 5             Banksville         5             4,144
# 6      Bedford Dwellings        15             1,202
# 8            Beltzhoover         6             1,925
# 10                 Bluff        15             6,600
# 11               Bon Air         6               808
# 14  California-Kirkbride         3               761
# 20        Chartiers City         4               477
# 21               Chateau         3                11
#
#     #Part 1 (Major Crime) Reports (2010)  #Part 2 Reports (2010)  \
# 1                                     38                      49
# 4                                     19                      37
# 5                                     62                      81
# 6                                     42                      80
# 8                                     83                     131
# 10                                   105                     191
# 11                                    26                      55
# 14                                    64                      89
# 20                                     9                      20
# 21                                    16                      24
#
#     #Other Police Reports (2010)  Part 1 Crime per 100 Persons (2010)  \
# 1                             31                                  8.2
# 4                             24                                  7.8
# 5                             61                                  1.5
# 6                             38                                  3.5
# 8                             85                                  4.3
# 10                           132                                  1.6
# 11                            38                                  3.2
# 14                            74                                  8.4
# 20                            15                                  1.9
# 21                            48                                145.5
#
#     Part 2 Crime per 100 Persons (2010)  #Murder (2010)  #Rape (2010)  \
# 1                                  10.6               1             0
# 4                                  15.2               0             0
# 5                                   2.0               0             0
# 6                                   6.7               0             0
# 8                                   6.8               1             0
# 10                                  2.9               0             0
# 11                                  6.8               0             0
# 14                                 11.7               1             0
# 20                                  4.2               0             0
# 21                                218.2               0             0
#
#     #Robbery (2010)  #Agr. Assault (2010)  #Burglary (2010)  \
# 1                 4                     6                 6
# 4                 4                     5                 5
# 5                 2                     5                 9
# 6                 7                     8                 8
# 8                 6                    10                28
# 10               12                    11                14
# 11                1                     4                 7
# 14                1                     6                12
# 20                0                     4                 2
# 21                1                     0                 0
#
#     #Auto Theft (2010)  #Drug Violations (2010)
# 1                    4                       12
# 4                    3                        7
# 5                    5                        7
# 6                    2                       25
# 8                    8                       38
# 10                  14                       37
# 11                   1                       11
# 14                   9                       48
# 20                   2                        3
# 21                   2                       14

# %%
def filter_func(crime, lower_bound):
    return (crime['#Robbery (2010)'] < lower_bound)

robberyFiltered = crime.groupby(crime.index).filter(filter_func, lower_bound=1)

robberyFiltered.head(10)
# Out:
#         Neighborhood  Sector # Population (2010)  \
# 20    Chartiers City         4               477
# 24  Duquesne Heights         6             2,425
# 26     East Carnegie         4               570
# 31         Fairywood         4             1,002
# 37              Hays         8               362
# 53        Mt. Oliver         7               509
# 54     New Homestead         8               990
# 66         Ridgemont         4               483
# 77         St. Clair         7               209
# 80       Summer Hill         1             1,051
#
#     #Part 1 (Major Crime) Reports (2010)  #Part 2 Reports (2010)  \
# 20                                     9                      20
# 24                                    55                      44
# 26                                     9                      11
# 31                                     3                       6
# 37                                    15                      17
# 53                                    12                      28
# 54                                     7                       4
# 66                                    14                      15
# 77                                    14                      10
# 80                                    13                      22
#
#     #Other Police Reports (2010)  Part 1 Crime per 100 Persons (2010)  \
# 20                            15                                  1.9
# 24                            50                                  2.3
# 26                            11                                  1.6
# 31                             9                                  0.3
# 37                             7                                  4.1
# 53                            16                                  2.4
# 54                             9                                  0.7
# 66                             7                                  2.9
# 77                            10                                  6.7
# 80                            13                                  1.2
#
#     Part 2 Crime per 100 Persons (2010)  #Murder (2010)  #Rape (2010)  \
# 20                                  4.2               0             0
# 24                                  1.8               0             0
# 26                                  1.9               0             0
# 31                                  0.6               0             0
# 37                                  4.7               0             0
# 53                                  5.5               0             1
# 54                                  0.4               0             0
# 66                                  3.1               0             0
# 77                                  4.8               0             0
# 80                                  2.1               0             0
#
#     #Robbery (2010)  #Agr. Assault (2010)  #Burglary (2010)  \
# 20                0                     4                 2
# 24                0                     4                21
# 26                0                     1                 5
# 31                0                     0                 1
# 37                0                     1                 5
# 53                0                     4                 1
# 54                0                     0                 1
# 66                0                     1                 3
# 77                0                     2                 2
# 80                0                     1                 2
#
#     #Auto Theft (2010)  #Drug Violations (2010)
# 20                   2                        3
# 24                   5                        2
# 26                   0                        0
# 31                   0                        0
# 37                   4                        1
# 53                   3                        2
# 54                   2                        1
# 66                   0                        2
# 77                   4                        0
# 80                   2                        1

# %%
environment = pd.read_csv("environment.csv")
environment.head()
environment[environment['Neighborhood'].str.startswith("Fairywood")].head()
# Out:
#    Neighborhood  Sector # Population (2010)    Land Area (acres)  \
# 31    Fairywood         4             1,002  0620-10-14T00:00:00
#
#    Landslide Prone (% land area) Undermined (% land area)  \
# 31                          6.3%                     0.0%
#
#    Flood Plain (% land area)  # Street Trees  Park Space (acres)  \
# 31                     11.9%               6                 7.4
#
#    Park Space (% of land area)  Park Space (acres/1000 pers.)  \
# 31                        1.2%                            7.3
#
#    Greenway (% of land area) Woodland (% of land area)  \
# 31                      0.0%                     24.7%
#
#    Cemetery (% of land area)
# 31                      0.0%
